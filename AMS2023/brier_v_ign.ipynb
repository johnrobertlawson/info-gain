# %%
import matplotlib.pyplot as plt

from lorenz63 import Lorenz63

# %%
L63 = Lorenz63(1,1,1,166.1,)

# %%
L63.integrate(5e3)
fig,ax = plt.subplots(1)
ax.plot(L63.get_z())
# Out:
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
#  [1.08255083]
#  [0.99974994]]
# [[1.0013205 ]
# ...
